# %%
cd ..
# Out:
# /home/avani/Desktop/IBM/src

# %%
import pandas as pd
log_dir = "PPO_logs/helpdesk/"
log_path = log_dir+"PPO_heldesk_0_setting3_.csv"
log_df = pd.read_csv(checkpoint_path)

# %%
log_df
# Out:
#      episode    reward  accuracy       mae        gs        gv
# 0          1  0.182851  0.591425  3.063856  0.808967  0.190546
# 1          2  0.188529  0.594265  3.061787  0.809454  0.190058
# 2          3  0.183135  0.591567  3.057329  0.807992  0.191520
# 3          4  0.178308  0.589154  3.066629  0.809942  0.189571
# 4          5  0.176604  0.588302  3.060424  0.808967  0.190546
# ..       ...       ...       ...       ...       ...       ...
# 995      996  0.702442  0.851221  3.065306  0.808967  0.190546
# 996      997  0.701590  0.850795  3.056480  0.809454  0.190058
# 997      998  0.699035  0.849517  3.065220  0.809454  0.190058
# 998      999  0.703861  0.851931  3.052555  0.809454  0.190058
# 999     1000  0.701306  0.850653  3.061528  0.809942  0.189571
#
# [1000 rows x 6 columns]

# %%
ax = log_df.plot(x='episode',y=['reward','accuracy'])

# %%
ax.figure.savefig(log_dir+"setting3.png")

# %%
log_df.plot(x='episode',y=['mae'])
# Out:
# <AxesSubplot:xlabel='episode'>

# %%
log_df.plot(x='episode',y=['gs'])
# Out:
# <AxesSubplot:xlabel='episode'>

# %%
log_df.plot(x='episode',y=['gv'])
# Out:
# <AxesSubplot:xlabel='episode'>
